# %%
from apis import okex
from time import time
from services import TSService
import os
from pipelines import Pipeline

# %%
os.getcwd()
# Out:
# 'c:\\Users\\tomsr\\Documents\\School\\aidi\\student projects\\crypto_bot\\server'

# %%
file = open(f"{os.getcwd()}/ts/model.pt")
print(file)
# Out:
# <_io.TextIOWrapper name='c:\\Users\\tomsr\\Documents\\School\\aidi\\student projects\\crypto_bot\\server/ts/model.pt' mode='r' encoding='cp1252'>

# %%
file.name
# Out:
# 'c:\\Users\\tomsr\\Documents\\School\\aidi\\student projects\\crypto_bot\\server/ts/model.pt'

# %%
file.close()

# %%
service = TSService()

# %%
okex.ohlcv(instId="ETH-USDT", limit="100", after=int(time())*1000)
# Out:
# {'code': '0',
#  'msg': '',
#  'data': [['1711917180000',
#    '3631.05',
#    '3631.05',
#    '3630.98',
#    '3630.98',
#    '1.223718',
#    '4443.37990817',
#    '4443.37990817',
#    '0'],
#   ['1711917120000',
#    '3632.59',
#    '3632.59',
#    '3631.23',
#    '3631.58',
#    '14.416009',
#    '52353.28166365',
#    '52353.28166365',
#    '1'],
#   ['1711917060000',
#    '3633.85',
#    '3633.86',
#    '3630.3',
#    '3632.6',
#    '41.461664',
#    '150578.30851164',
#    '150578.30851164',
#    '1'],
#   ['1711917000000',
#    '3635.56',
#    '3636.42',
#    '3633.75',
#    '3633.81',
#    '58.745833',
#    '213520.71198428',
#    '213520.71198428',
#    '1'],
#   ['1711916940000',
#    '3635.8',
#    '3635.88',
#    '3635.55',
#    '3635.61',
#    '7.995818',
#    '29069.65516163',
#    '29069.65516163',
#    '1'],
#   ['1711916880000',
#    '3633.76',
#    '3636.12',
#    '3633.6',
#    '3635.8',
#    '20.027616',
#    '72786.18490182',
#    '72786.18490182',
#    '1'],
# ...

# %%
test = service.fetch()
